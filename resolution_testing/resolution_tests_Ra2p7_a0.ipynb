# %%
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#wave_more = np.genfromtxt('adm_code_v4/a0_k1_xp01_ra2p7_m1/wavelengths_vvinf.dat', skip_header=1, unpack=True)
#m1_abs = np.genfromtxt('adm_code_v4/a0_k1_xp01_ra2p7_m1/prof_abs.dat', skip_header=1, unpack=True)
#m1_emit = np.genfromtxt('adm_code_v4/a0_k1_xp01_ra2p7_m1/prof_emit.dat', skip_header=1, unpack=True)

wave = np.genfromtxt('adm_code_v4/resolution_testing/dxp1_dyp1_dzp1_lp1/wavelengths_vvinf.dat', skip_header=1, unpack=True)
m2_abs = np.genfromtxt('adm_code_v4/resolution_testing/dxp1_dyp1_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
m2_emit = np.genfromtxt('adm_code_v4/resolution_testing/dxp1_dyp1_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

m3_abs = np.genfromtxt('adm_code_v4/resolution_testing/dxp1_dyp1_dzp01_lp1/prof_abs.dat', skip_header=1, unpack=True)
m3_emit = np.genfromtxt('adm_code_v4/resolution_testing/dxp1_dyp1_dzp01_lp1/prof_emit.dat', skip_header=1, unpack=True)

# Shayol Comps

wave_more = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp1_lp01/wavelengths_vvinf.dat', skip_header=1, unpack=True) 

#s2: all regular
s2_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s2_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s3: z
s3_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp01_lp1/prof_abs.dat', skip_header=1, unpack=True)
s3_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp01_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s4: l
s4_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s4_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s5: y
s5_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp01_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s5_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp01_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s6: x
s6_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp1_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s6_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp1_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s7: z, l
s7_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp01_lp01/prof_abs.dat', skip_header=1, unpack=True)
s7_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp1_dzp01_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s8: y, l
s8_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp01_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s8_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp1_dyp01_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s9: x, l
s9_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp1_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s9_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp1_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s10: x, y
s10_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp01_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s10_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp01_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s11: x, y, z
s11_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp01_dzp01_lp1/prof_abs.dat', skip_header=1, unpack=True)
s11_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp01_dyp01_dzp01_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s12: xp05, yp05, zp01, lp05
wave_half = np.genfromtxt('adm_code_v4/shayol_comps/dxp05_dyp05_dzp01_lp05/wavelengths_vvinf.dat', skip_header=1, unpack=True) 
s12_abs = np.genfromtxt('adm_code_v4/shayol_comps/dxp05_dyp05_dzp01_lp05/prof_abs.dat', skip_header=1, unpack=True)
s12_emit = np.genfromtxt('adm_code_v4/shayol_comps/dxp05_dyp05_dzp01_lp05/prof_emit.dat', skip_header=1, unpack=True)

# p-tests
p00_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx1_dy1_dz1_lp01/prof_abs.dat', skip_header=1, unpack=True)
p00_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx1_dy1_dz1_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p0_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx3_dy3_dz3_lp01/prof_abs.dat', skip_header=1, unpack=True)
p0_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx3_dy3_dz3_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p1_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy5_dz5_lp01/prof_abs.dat', skip_header=1, unpack=True)
p1_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy5_dz5_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p2_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy5_dz7_lp01/prof_abs.dat', skip_header=1, unpack=True)
p2_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy5_dz7_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p3_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy7_dz5_lp01/prof_abs.dat', skip_header=1, unpack=True)
p3_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy7_dz5_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p4_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy5_dz5_lp01/prof_abs.dat', skip_header=1, unpack=True)
p4_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy5_dz5_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p5_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy7_dz7_lp01/prof_abs.dat', skip_header=1, unpack=True)
p5_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx5_dy7_dz7_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p6_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy5_dz7_lp01/prof_abs.dat', skip_header=1, unpack=True)
p6_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy5_dz7_lp01/prof_emit.dat', skip_header=1, unpack=True) 

p7_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy7_dz5_lp01/prof_abs.dat', skip_header=1, unpack=True)
p7_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy7_dz5_lp01/prof_emit.dat', skip_header=1, unpack=True)

p8_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy7_dz7_lp01/prof_abs.dat', skip_header=1, unpack=True)
p8_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx7_dy7_dz7_lp01/prof_emit.dat', skip_header=1, unpack=True)

p9_abs = np.genfromtxt('adm_code_v4/shayol_comps/dx12_dy12_dz12_lp01/prof_abs.dat', skip_header=1, unpack=True)
p9_emit = np.genfromtxt('adm_code_v4/shayol_comps/dx12_dy12_dz12_lp01/prof_emit.dat', skip_header=1, unpack=True)

p10_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx5_dy5_dz5_lp01/prof_abs.dat', skip_header=1, unpack=True)
p10_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx5_dy5_dz5_lp01/prof_emit.dat', skip_header=1, unpack=True)

p11_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx7_dy7_dz7_lp01/prof_abs.dat', skip_header=1, unpack=True)
p11_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx7_dy7_dz7_lp01/prof_emit.dat', skip_header=1, unpack=True)

p12_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx10_dy10_dz10_lp01/prof_abs.dat', skip_header=1, unpack=True)
p12_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx10_dy10_dz10_lp01/prof_emit.dat', skip_header=1, unpack=True)

p13_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx12_dy12_dz12_lp01/prof_abs.dat', skip_header=1, unpack=True)
p13_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx12_dy12_dz12_lp01/prof_emit.dat', skip_header=1, unpack=True)

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 
#plt.plot(-wave_more,m1_abs+m1_emit, color='blue', ls='--', label='350 wavelength points')
#plt.plot(-wave,m2_abs+m2_emit, color='gray', label='35 wavelength points')

#plt.scatter(-wave,m2_abs+m2_emit, color='gray', label='Christi, 35 wvl, dz=0.1')
#plt.scatter(-wave,s2_abs+s2_emit, color='blue', label='Shayol, 35 wvl, dz=0.1')

plt.scatter(-wave,m3_abs+m3_emit, color='gray', label='Christi, 35 wvl, dz=0.01')
plt.scatter(-wave,s3_abs+s3_emit, color='blue', label='Shayol, 35 wvl, dz=0.01')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 
plt.plot(-wave_more,s7_abs+s7_emit, color='cornflowerblue', ls='-', label='z, l', marker='o')
#plt.plot(-wave_half,s12_abs+s12_emit, color='coral', ls='-', label='halves', marker='o')

#plt.plot(-wave,s2_abs+s2_emit, color='k', ls='--', label='reg')
plt.plot(-wave,s3_abs+s3_emit, color='r', ls='-.', label='z', marker='o')
#plt.plot(-wave_more,s4_abs+s4_emit, color='orange', ls='-.', label='l', marker='o')
#plt.plot(-wave,s5_abs+s5_emit, color='gold', ls='-.', label='y')
#plt.plot(-wave,s6_abs+s6_emit, color='g', ls='-.', label='x')
#plt.plot(-wave_more,s7_abs+s7_emit, color='cornflowerblue', ls='-', label='z, l', marker='o')
#plt.plot(-wave_more,s8_abs+s8_emit, color='b', ls='-', label='y, l')
#plt.plot(-wave_more,s9_abs+s9_emit, color='violet', ls='-', label='x, l')
#plt.plot(-wave,s10_abs+s10_emit, color='purple', ls='-', label='x, y')
#plt.plot(-wave,s11_abs+s11_emit, color='brown', ls='-', label='x, y, z', marker='o')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots

#plt.plot(-wave,s2_abs, color='k', ls='--', label='reg')
#plt.plot(-wave,s3_abs, color='r', ls='-.', label='z')
plt.plot(-wave_more,s4_abs, color='orange', ls='-.', label='l')
#plt.plot(-wave,s5_abs, color='gold', ls='-.', label='y')
#plt.plot(-wave,s6_abs, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_abs, color='cornflowerblue', ls='-', label='z, l')
#plt.plot(-wave_more,s8_abs, color='b', ls='-', label='y, l')
#plt.plot(-wave_more,s9_abs, color='violet', ls='-', label='x, l')
#plt.plot(-wave,s10_abs, color='purple', ls='-', label='x, y')
#plt.plot(-wave,s11_abs, color='brown', ls='--', label='x, y, z')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots

plt.plot(-wave,s2_emit, color='k', ls='--', label='reg')
plt.plot(-wave,s3_emit, color='r', ls='-.', label='z')
plt.plot(-wave_more,s4_emit, color='orange', ls='-.', label='l')
plt.plot(-wave,s5_emit, color='gold', ls='-.', label='y')
plt.plot(-wave,s6_emit, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_emit, color='cornflowerblue', ls='-', label='z, l')
plt.plot(-wave_more,s8_emit, color='b', ls='-', label='y, l')
plt.plot(-wave_more,s9_emit, color='violet', ls='-', label='x, l')
plt.plot(-wave,s10_emit, color='purple', ls='-', label='x, y')
plt.plot(-wave,s11_emit, color='brown', ls='--', label='x, y, z')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 


plt.plot(-wave_more,p0_abs+p0_emit, color='r', ls='--', label='all_3')
plt.plot(-wave_more,p1_abs+p1_emit, color='g', ls='--', label='all_5')
#plt.plot(-wave_more,p2_abs+p2_emit, color='r', ls='-.', label='z')
#plt.plot(-wave_more,p3_abs+p3_emit, color='orange', ls='-.', label='y')
#plt.plot(-wave_more,p4_abs+p4_emit, color='gold', ls='-.', label='x')
#plt.plot(-wave_more,p5_abs+p5_emit, color='g', ls='-', label='y, z')
#plt.plot(-wave_more,p6_abs+p6_emit, color='b', ls='-', label='x, z')
#plt.plot(-wave_more,p7_abs+p7_emit, color='purple', ls='-', label='x, y')
plt.plot(-wave_more,p8_abs+p8_emit, color='b', ls='--', label='all_7')
plt.plot(-wave_more,s4_abs+s4_emit, color='purple', ls='--', label='all_10')
plt.plot(-wave_more,p9_abs+p9_emit, color='brown', ls='--', label='all_12')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 

plt.plot(-wave_more,p1_abs, color='brown', ls='--', label='all_5')
plt.plot(-wave_more,p2_abs, color='r', ls='-.', label='z')
plt.plot(-wave_more,p3_abs, color='orange', ls='-.', label='y')
plt.plot(-wave_more,p4_abs, color='gold', ls='-.', label='x')
plt.plot(-wave_more,p5_abs, color='g', ls='-', label='y, z')
plt.plot(-wave_more,p6_abs, color='b', ls='-', label='x, z')
plt.plot(-wave_more,p7_abs, color='purple', ls='-', label='x, y')
plt.plot(-wave_more,p8_abs, color='gray', ls='--', label='all_7')
#plt.plot(-wave_more,s4_abs+s4_emit, color='k', ls='--', label='all_10')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 

plt.plot(-wave_more,p1_emit, color='brown', ls='--', label='all_5')
plt.plot(-wave_more,p2_emit, color='r', ls='-.', label='z')
plt.plot(-wave_more,p3_emit, color='orange', ls='-.', label='y')
plt.plot(-wave_more,p4_emit, color='gold', ls='-.', label='x')
plt.plot(-wave_more,p5_emit, color='g', ls='-', label='y, z')
plt.plot(-wave_more,p6_emit, color='b', ls='-', label='x, z')
plt.plot(-wave_more,p7_emit, color='purple', ls='-', label='x, y')
plt.plot(-wave_more,p8_emit, color='gray', ls='--', label='all_7')
#plt.plot(-wave_more,s4_abs+s4_emit, color='k', ls='--', label='all_10')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.7)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 

plt.scatter(-wave_more,p13_abs+p13_emit, color='k', s=20, label='all_12')
plt.scatter(-wave_more,p12_abs+p12_emit, color='red', s=5, label='all_10')
#plt.scatter(-wave_more,p11_abs+p11_emit, color='b', s=10, label='all_7')

#plt.plot(-wave_more,p13_abs+p13_emit, color='purple', ls='-', label='all_12')
#plt.plot(-wave_more,p12_abs+p12_emit, color='b', ls='-', label='all_10')
#plt.plot(-wave_more,p11_abs+p11_emit, color='r', ls='--', label='all_7')
#plt.plot(-wave_more,p10_abs+p10_emit, color='red', ls='-', label='all_5')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()
