# %%
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
wave = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp01_lp1/wavelengths_vvinf.dat', skip_header=1, unpack=True)
wave_half = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp05_dyp05_dzp01_lp05/wavelengths_vvinf.dat', skip_header=1, unpack=True) 
wave_more = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx10_dy10_dz10_lp01/wavelengths_vvinf.dat', skip_header=1, unpack=True) 

m1_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx10_dy10_dz10_lp01/prof_abs.dat', skip_header=1, unpack=True)
m1_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dx10_dy10_dz10_lp01/prof_emit.dat', skip_header=1, unpack=True)

# Shayol Comps

#s2: all regular
#s2_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
#s2_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s3: z
s3_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp01_lp1/prof_abs.dat', skip_header=1, unpack=True)
s3_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp01_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s4: l
s4_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s4_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s5: y
s5_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp01_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s5_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp01_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s6: x
s6_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp1_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s6_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp1_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s7: z, l
s7_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp01_lp01/prof_abs.dat', skip_header=1, unpack=True)
s7_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp1_dzp01_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s8: y, l
s8_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp01_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s8_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp1_dyp01_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s9: x, l
s9_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp1_dzp1_lp01/prof_abs.dat', skip_header=1, unpack=True)
s9_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp1_dzp1_lp01/prof_emit.dat', skip_header=1, unpack=True)

#s10: x, y
s10_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp01_dzp1_lp1/prof_abs.dat', skip_header=1, unpack=True)
s10_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp01_dzp1_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s11: x, y, z
s11_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp01_dzp01_lp1/prof_abs.dat', skip_header=1, unpack=True)
s11_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp01_dyp01_dzp01_lp1/prof_emit.dat', skip_header=1, unpack=True)

#s12: halfs
s12_abs = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp05_dyp05_dzp01_lp05/prof_abs.dat', skip_header=1, unpack=True)
s12_emit = np.genfromtxt('adm_code_v4/shayol_comps/ra10_dxp05_dyp05_dzp01_lp05/prof_emit.dat', skip_header=1, unpack=True)

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 
#plt.plot(-wave_more,m1_abs+m1_emit, color='blue', ls='--', label='350 wavelength points')
#plt.plot(-wave,m2_abs+m2_emit, color='gray', label='35 wavelength points')

#plt.scatter(-wave,m2_abs+m2_emit, color='gray', label='Christi, 35 wvl, dz=0.1')
#plt.scatter(-wave,s2_abs+s2_emit, color='blue', label='Shayol, 35 wvl, dz=0.1')

plt.scatter(-wave,m3_abs+m3_emit, color='gray', label='Christi, 35 wvl, dz=0.01')
plt.scatter(-wave,s3_abs+s3_emit, color='blue', label='Shayol, 35 wvl, dz=0.01')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.7)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 

#plt.plot(-wave,s2_abs+s2_emit, color='k', ls='--', label='reg')
#plt.plot(-wave,s3_abs+s3_emit, color='r', ls='-.', label='z')
#plt.plot(-wave_more,s4_abs+s4_emit, color='orange', ls='-.', label='l')
#plt.plot(-wave,s5_abs+s5_emit, color='gold', ls='-.', label='y')
#plt.plot(-wave,s6_abs+s6_emit, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_abs+s7_emit, color='cornflowerblue', ls='-', label='z, l', marker='o')
#plt.plot(-wave_more,s8_abs+s8_emit, color='b', ls='-', label='y, l')
#plt.plot(-wave_more,s9_abs+s9_emit, color='violet', ls='-', label='x, l')
#plt.plot(-wave,s10_abs+s10_emit, color='purple', ls='-', label='x, y')
#plt.plot(-wave,s11_abs+s11_emit, color='brown', ls='-', label='x, y, z')
plt.plot(-wave_half,s12_abs+s12_emit, color='coral', ls='-', label='halves', marker='o')

plt.title('a=0.0, k=1.0, x=0.01, Ra=10.0, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.7)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots 

#plt.plot(-wave,s2_abs+s2_emit, color='k', ls='--', label='reg')
#plt.plot(-wave,s3_abs+s3_emit, color='r', ls='-.', label='z')
#plt.plot(-wave_more,s4_abs+s4_emit, color='orange', ls='-.', label='l')
#plt.plot(-wave,s5_abs+s5_emit, color='gold', ls='-.', label='y')
#plt.plot(-wave,s6_abs+s6_emit, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_abs+s7_emit, color='cornflowerblue', ls='-', label='z, l',marker='o')
#plt.plot(-wave_more,s8_abs+s8_emit, color='b', ls='-', label='y, l')
plt.plot(-wave_more,s9_abs+s9_emit, color='violet', ls='-', label='x, l',marker='o')
#plt.plot(-wave,s10_abs+s10_emit, color='purple', ls='-', label='x, y')
#plt.plot(-wave,s11_abs+s11_emit, color='brown', ls='-', label='x, y, z',marker='o')
plt.plot(-wave_half,s12_abs+s12_emit, color='gray', ls='-', label='halfs',marker='o')

plt.title('a=0.0, k=1.0, x=0.01, Ra=10.0, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots

#plt.plot(-wave,s2_abs, color='k', ls='--', label='reg')
plt.plot(-wave,s3_abs, color='r', ls='-.', label='z')
plt.plot(-wave_more,s4_abs, color='orange', ls='-.', label='l')
plt.plot(-wave,s5_abs, color='gold', ls='-.', label='y')
plt.plot(-wave,s6_abs, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_abs, color='cornflowerblue', ls='-', label='z, l')
plt.plot(-wave_more,s8_abs, color='b', ls='-', label='y, l')
plt.plot(-wave_more,s9_abs, color='violet', ls='-', label='x, l')
plt.plot(-wave,s10_abs, color='purple', ls='-', label='x, y')
plt.plot(-wave,s11_abs, color='brown', ls='--', label='x, y, z')
plt.plot(-wave_half,s12_abs, color='gray', ls='-', label='halfs',marker='o')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig = plt.figure(figsize=(7,7))
plt.rcParams.update({'font.size': 14,'font.family':'Times new roman'})

plt.xlim(-2.0,1.5)
#plt.xlabel('$\lambda \; (v/v_{\infty})$')
plt.ylim(0.0,1.4)
#plt.ylabel('$F_{\lambda}/F_{C}$')

# Plot Line Center
plt.axvline(x=0, ls='--', color='gray')

#Plots

#plt.plot(-wave,s2_emit, color='k', ls='--', label='reg')
plt.plot(-wave,s3_emit, color='r', ls='-.', label='z')
plt.plot(-wave_more,s4_emit, color='orange', ls='-.', label='l')
plt.plot(-wave,s5_emit, color='gold', ls='-.', label='y')
plt.plot(-wave,s6_emit, color='g', ls='-.', label='x')
plt.plot(-wave_more,s7_emit, color='cornflowerblue', ls='-', label='z, l')
plt.plot(-wave_more,s8_emit, color='b', ls='-', label='y, l')
plt.plot(-wave_more,s9_emit, color='violet', ls='-', label='x, l')
plt.plot(-wave,s10_emit, color='purple', ls='-', label='x, y')
plt.plot(-wave,s11_emit, color='brown', ls='--', label='x, y, z')
plt.plot(-wave_half,s12_emit, color='gray', ls='-', label='halfs',marker='o')

plt.title('a=0.0, k=1.0, x=0.01, Ra=2.7, O+C Loops')
plt.legend(loc='best')

# End Matter
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>
